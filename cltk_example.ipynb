# %% [markdown]
# <a href="https://colab.research.google.com/github/OdysseusPolymetis/motif2023/blob/main/cltk_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install cltk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 845.5/845.5 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 58.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 48.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 32.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 51.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 27.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 61.6 MB/s eta 0:00:00
# ...

# %%
from cltk import NLP

# %%
cltk_lat = NLP(language="lat")
# Out:
# ‎𐤀 CLTK version '1.1.7'.
# Pipeline for language 'Latin' (ISO: 'lat'): `LatinNormalizeProcess`, `LatinStanzaProcess`, `LatinEmbeddingsProcess`, `StopsProcess`, `LatinLexiconProcess`.

# %%
cltk_doc = cltk_lat.analyze(text="Lorem ipsum dolor sit amet, consectetur adipisci velit. ")
# Out:
# CLTK message: This part of the CLTK depends upon the Stanza NLP library.
# CLTK message: Allow download of Stanza models to ``/root/stanza_resources/la/tokenize/ittb.pt``? [Y/n]
# y
# ...
# INFO:stanza:Downloading these customized packages for language: la (Latin)...
# ...
# | Processor | Package       |
# -----------------------------
# | tokenize  | ittb          |
# | pos       | ittb_nocharlm |
# | lemma     | ittb_nocharlm |
# | depparse  | ittb_nocharlm |
# | pretrain  | conll17       |
# ...
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.
# CLTK message: This part of the CLTK depends upon word embedding models from the Fasttext project.
# Do you want to download file 'https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.la.vec' to '/root/cltk_data/lat/embeddings/fasttext/wiki.la.vec'? [Y/n]
# y
# 100%|██████████| 364M/364M [00:09<00:00, 38.8MiB/s]
# ...

# %%
for elem in cltk_doc:
  print(elem.string)
  print(elem.lemma)
  print(elem.upos)
  print("XXXXXXXXXXX")
# Out:
# Lorem
# Lorem
# SCONJ
# XXXXXXXXXXX
# ipsum
# ipse
# DET
# XXXXXXXXXXX
# dolor
# dolor
# NOUN
# XXXXXXXXXXX
# sit
# sum
# AUX
# XXXXXXXXXXX
# amet
# amo
# VERB
# XXXXXXXXXXX
# ,
# ,
# PUNCT
# XXXXXXXXXXX
# consectetur
# conseqtor
# VERB
# XXXXXXXXXXX
# adipisci
# adipiscor
# VERB
# XXXXXXXXXXX
# velit
# velit
# VERB
# XXXXXXXXXXX
# .
# .
# PUNCT
# XXXXXXXXXXX
